# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv('Customers (1).csv')

# %%
ds.head()
# Out:
#    CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 0           1    Male   19          15000              39     Healthcare
# 1           2    Male   21          35000              81       Engineer
# 2           3  Female   20          86000               6       Engineer
# 3           4  Female   23          59000              77         Lawyer
# 4           5  Female   31          38000              40  Entertainment
#
#    Work_Experience  Family Size Spending_Category  Invoice_Number
# 0                1            4           Average          458984
# 1                3            3              High          458994
# 2                1            1               Low          458994
# 3                0            2              High          458997
# 4                2            6           Average          458999

# %%
ds.tail()
# Out:
#       CustomerID  Gender  Age  Annual_Income  Spending_Score     Profession  \
# 1995        1996  Female   71         184387              40         Artist
# 1996        1997  Female   91          73158              32         Doctor
# 1997        1998    Male   87          90961              14     Healthcare
# 1998        1999    Male   77         182109               4      Executive
# 1999        2000    Male   90         110610              52  Entertainment
#
#       Work_Experience  Family Size Spending_Category  Invoice_Number
# 1995                8            7           Average          461768
# 1996                7            7           Average          461773
# 1997                9            2               Low          461774
# 1998                7            2               Low          461775
# 1999                5            2              High          461775

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         2000 non-null   int64
#  1   Gender             2000 non-null   object
#  2   Age                2000 non-null   int64
#  3   Annual_Income      2000 non-null   int64
#  4   Spending_Score     2000 non-null   int64
#  5   Profession         1965 non-null   object
#  6   Work_Experience    2000 non-null   int64
#  7   Family Size        2000 non-null   int64
#  8   Spending_Category  2000 non-null   object
#  9   Invoice_Number     2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %%
ds1=ds.fillna('unknown')

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         2000 non-null   int64
#  1   Gender             2000 non-null   object
#  2   Age                2000 non-null   int64
#  3   Annual_Income      2000 non-null   int64
#  4   Spending_Score     2000 non-null   int64
#  5   Profession         2000 non-null   object
#  6   Work_Experience    2000 non-null   int64
#  7   Family Size        2000 non-null   int64
#  8   Spending_Category  2000 non-null   object
#  9   Invoice_Number     2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %%
ds2=pd.DataFrame(ds1,columns=['CustomerID', 'Gender',' Age', 'Annual_Income', 'Spending_Score', 'Profession',' Work_Experience', 'Family Size', 'Spending_Category', 'Invoice_Number'])

d=ds2[ds2.duplicated()]
print(d)
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender,  Age, Annual_Income, Spending_Score, Profession,  Work_Experience, Family Size, Spending_Category, Invoice_Number]
# Index: []

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([0,1,5])
y=np.array([0,10,50])
plt.plot(x,y,marker='*')
plt.show()

# %%
xp=ds.loc[:,'Annual_Income']
xv=xp.values
yp=ds.loc[:,'Spending_Score']
yv=yp.values
fig=plt.figure()
fig.set_figheight(10)
fig.set_figwidth(10)
plt.plot(xv,yv,marker="o",linestyle="dashed",color='r',ms=5,mec='b',mfc='y')

# %%
xp=ds.loc[:,'Annual_Income']
xv=xp.values
yp=ds.loc[:,'Spending_Score']
yv=yp.values
fig=plt.figure()
fig.set_figheight(10)
fig.set_figwidth(10)
plt.xlabel('Salary',fontsize=20)
plt.ylabel('spending score',fontsize=20)
plt.xticks(rotation=20)
plt.title('salary vs spending score')
plt.plot(xv,yv,marker="o",linestyle="dashed",color='r',ms=5,mec='b',mfc='y',label='naseeha is cute')

# %%
y=np.array([87,52,65,12,15])
l=['entertainment','leaisure','eating','sleeping','work']
plt.pie(y,labels=l,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x18bc2c2f950>,
# ...
#  [Text(-1.0184010903180087, 0.415763417389134, 'entertainment'),
#   Text(-0.07474230526416412, -1.0974577840645163, 'leaisure'),
#   Text(1.098754065676397, -0.052340263273966264, 'eating'),
#   Text(0.5947050557442811, 0.9253787855101236, 'sleeping'),
#   Text(0.22284646260857036, 1.077190537510819, 'work')])

# %%
ds['Profession'].value_counts()
# Out:
# Profession
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: count, dtype: int64
